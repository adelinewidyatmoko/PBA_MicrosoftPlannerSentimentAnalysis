# %%
# !pip install google_play_scraper
# !pip install textblob
# Out:
# Requirement already satisfied: google_play_scraper in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (1.2.7)
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the 'C:\Users\USER\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: textblob in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from textblob) (3.9.2)
# Requirement already satisfied: joblib in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: click in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from nltk>=3.9->textblob) (2026.1.15)
# Requirement already satisfied: tqdm in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from nltk>=3.9->textblob) (4.67.3)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the 'C:\Users\USER\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (3.9.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.60.2)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the 'C:\Users\USER\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
from google_play_scraper import app , Sort , reviews_all
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.dates as dates

# %%
nhs_reviews = reviews_all(
    'com.microsoft.planner',
    sleep_milliseconds=0,
    lang='en',
    sort=Sort.NEWEST
)

# %%
print(nhs_reviews[:5])
# Out:
# [{'reviewId': '4ffe5822-3388-42d6-b0aa-0b637d397320', 'userName': 'Matthew Pieterse', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV-BGj8v0DGBN9R7-6P8UaXlhoU2PjWKVTPs4Rqy-ZVxm_s5m4z-w', 'content': 'Lagging far behind the desktop/web UI experience. The mobile version is very unappealing and painful to navigate.', 'score': 1, 'thumbsUpCount': 0, 'reviewCreatedVersion': '1.18.36', 'at': datetime.datetime(2026, 3, 24, 22, 39, 25), 'replyContent': None, 'repliedAt': None, 'appVersion': '1.18.36'}, {'reviewId': '12098749-597c-4c0c-afbd-ee6285b78449', 'userName': 'Ephraim Nkemachor', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUx0RR2ax3Vf0GmZVQaVHhxIxls02V7pXXPUnvmeQj6YXilAMxxgg', 'content': 'interface barely ever works', 'score': 1, 'thumbsUpCount': 0, 'reviewCreatedVersion': '1.18.31', 'at': datetime.datetime(2026, 3, 23, 22, 1, 55), 'replyContent': None, 'repliedAt': None, 'appVersion': '1.18.31'}, {'reviewId': '0241cd90-484f-442d-86ad-0b84b6d865f6', 'userName': '딸기', 'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK-90Ky519xeeULz2qm6SmmAzF6PsIjTm_YEfvPXD8tolST8Q=mo', 'content': "it's good but hope there'll be notification feature for comment and things..", 'score': 4, 'thumbsUpCount': 0, 'reviewCreatedVersion': None, 'at': datetime.datetime(2026, 3, 12, 9, 21, 46), 'replyContent': None, 'repliedAt': None, 'appVersion': None}, {'reviewId': 'd5a759cd-b785-4818-a4ea-f80ee119074e', 'userName': 'Tom O', 'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIJ53sW1SUI0PvbilfCFwYWt5BTFF85ki9NGUAvgxKm6iIJug=mo', 'content': 'I can only see one of many plans', 'score': 1, 'thumbsUpCount': 0, 'reviewCreatedVersion': '1.18.36', 'at': datetime.datetime(2026, 3, 11, 5, 14, 39), 'replyContent': None, 'repliedAt': None, 'appVersion': '1.18.36'}, {'reviewId': 'f5a76d6b-6e4c-44da-b1a6-d1cdb641ec59', 'userName': 'Roke Beedell (RokeJulianLockhart)', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU4v4CnXn7EhHdDZlxJ3wPiR4IPDDMQdfrP9rst3oRuVIgYcyZ9', 'content': 'Does not integrate with To-Do.', 'score': 2, 'thumbsUpCount': 0, 'reviewCreatedVersion': None, 'at': datetime.datetime(2026, 3, 9, 18, 37, 37), 'replyContent': None, 'repliedAt': None, 'appVersion': None}]

# %%
df_nhsrev = pd.DataFrame(np.array(nhs_reviews),columns=['content'])
df_nhsrev = df_nhsrev.join(pd.DataFrame(df_nhsrev.pop('content').tolist()))
df_nhsrev.to_csv(r'C:\Users\USER\Documents\PBA\Week2\Scrapping_sentimentAnalysis_Assignment\df_plannerReview.csv',index=False)
df_nhsrev.head()
# Out:
#                                reviewId                           userName  \
# 0  4ffe5822-3388-42d6-b0aa-0b637d397320                   Matthew Pieterse
# 1  12098749-597c-4c0c-afbd-ee6285b78449                  Ephraim Nkemachor
# 2  0241cd90-484f-442d-86ad-0b84b6d865f6                                 딸기
# 3  d5a759cd-b785-4818-a4ea-f80ee119074e                              Tom O
# 4  f5a76d6b-6e4c-44da-b1a6-d1cdb641ec59  Roke Beedell (RokeJulianLockhart)
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Lagging far behind the desktop/web UI experien...      1              0
# 1                        interface barely ever works      1              0
# 2  it's good but hope there'll be notification fe...      4              0
# 3                   I can only see one of many plans      1              0
# 4                     Does not integrate with To-Do.      2              0
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0              1.18.36 2026-03-24 22:39:25         None       NaT    1.18.36
# 1              1.18.31 2026-03-23 22:01:55         None       NaT    1.18.31
# 2                 None 2026-03-12 09:21:46         None       NaT       None
# 3              1.18.36 2026-03-11 05:14:39         None       NaT    1.18.36
# 4                 None 2026-03-09 18:37:37         None       NaT       None

# %%
#clean the content column (impossible because we cannot control people's reviews) 
# EDA (Explnatory Data Analysis ) 
#1. size of the data :
def shape(df):
    rows,col = df.shape
    print(f"the dataset contains {rows} reviews and {col} columns.")
shape(df_nhsrev)
# Out:
# the dataset contains 2843 reviews and 11 columns.

# %%
#2. rating distribution : to evaluate the order through the data score. 
#It is stated the valued for the highest stake comes down at 1 rating (39.74%) while the lowest at 4 rating (8.78%). 
df_rating = df_nhsrev["score"].value_counts().sort_index().plot(kind="bar")

# %%
def rating_summarize(df): 
    rating_score = df_nhsrev['score'].value_counts().sort_index()
    total = len(df)

    for rating, count in rating_score.items():
         percent = round((count/total)*100,2)
         print(f"{rating} star : {count} reviews ({percent}%)")
rating_summarize(df_nhsrev)
# Out:
# 1 star : 553 reviews (19.45%)
# 2 star : 170 reviews (5.98%)
# 3 star : 270 reviews (9.5%)
# 4 star : 567 reviews (19.94%)
# 5 star : 1283 reviews (45.13%)

# %%
df_nhsrev["review_length"] = df_nhsrev.content.str.len()
df_nhsrev["review_length"].describe()
# Out:
# count    2843.000000
# mean       87.628210
# std        97.099048
# min         1.000000
# 25%        22.000000
# 50%        55.000000
# 75%       116.000000
# max       931.000000
# Name: review_length, dtype: float64

# %%
#3. Checking most common words 
all_text = " ".join(df_nhsrev["content"].astype(str))
print(all_text[:500])
# Out:
# Lagging far behind the desktop/web UI experience. The mobile version is very unappealing and painful to navigate. interface barely ever works it's good but hope there'll be notification feature for comment and things.. I can only see one of many plans Does not integrate with To-Do. Not compatible with premium plan. Useless app. Principally a good app but pretty much unusable if you're using more than one MS account on one device. For Word, Excel and other MS apps it's pretty eas to switch but no

# %%
#DATA PREPROCESSING
# Lower casing

# Change the reviews type to string
df_nhsrev['content'] = df_nhsrev['content'].astype(str)# Before lowercasing
# Before lowercasing
print(df_nhsrev['content'].head())
# Out:
# 0    Lagging far behind the desktop/web UI experien...
# 1                          interface barely ever works
# 2    it's good but hope there'll be notification fe...
# 3                     I can only see one of many plans
# 4                       Does not integrate with To-Do.
# Name: content, dtype: object

# %%
#lowercasing the reviews 
#Lowercase all reviews to see the difference
df_nhsrev['content']= df_nhsrev['content'].apply(lambda x: x.lower())
print(df_nhsrev['content'].head())
# Out:
# 0    lagging far behind the desktop/web ui experien...
# 1                          interface barely ever works
# 2    it's good but hope there'll be notification fe...
# 3                     i can only see one of many plans
# 4                       does not integrate with to-do.
# Name: content, dtype: object

# %%
#REMOVE PUNCTUATION 
import re

df_nhsrev["content"] = df_nhsrev["content"].apply(lambda x: re.sub(r"[^\w\s]", "", x))
print(df_nhsrev["content"].tail())
# Out:
# 2838    limited functionality  cant add tasks or plans...
# 2839                                           works well
# 2840    fantastic this is what i was waiting for and i...
# 2841    a good first version excited for more planner ...
# 2842                                     clean and simple
# Name: content, dtype: object

# %%
#REMOVE STOPWORDS
# !pip install nltk
import nltk
nltk.download('stopwords')
# Out:
# Requirement already satisfied: nltk in c:\users\user\miniconda3\lib\site-packages (3.9.3)
# Requirement already satisfied: click in c:\users\user\miniconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\user\miniconda3\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\miniconda3\lib\site-packages (from nltk) (2026.2.28)
# Requirement already satisfied: tqdm in c:\users\user\miniconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\user\miniconda3\lib\site-packages (from click->nltk) (0.4.6)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.probability import FreqDist
stop_words = set(stopwords.words("english"))

# %%
df_nhsrev["content"] = df_nhsrev["content"].apply(
    lambda x: " ".join(word for word in x.split() if word not in stop_words)
)

# %%
df_nhsrev["content"].tail()
# Out:
# 2838    limited functionality cant add tasks plans nor...
# 2839                                           works well
# 2840                  fantastic waiting looks works great
# 2841      good first version excited planner capabilities
# 2842                                         clean simple
# Name: content, dtype: object

# %%
df_nhsrev.to_csv(
r'C:\Users\USER\Documents\PBA\Week2\Scrapping_sentimentAnalysis_Assignment\planner_clean_reviews.csv', index=False
)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\user\miniconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\user\miniconda3\lib\site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\user\miniconda3\lib\site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\user\miniconda3\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\user\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\user\miniconda3\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
#COUNT WORD FREQUENCY 

import seaborn as sns
import matplotlib.pyplot as plt
def freq_words(x, terms = 30):
    all_words = ''.join([text for text in x])
    all_words = all_words.split()

    fdist = FreqDist(all_words)
    words_df_nhsrev = pd.DataFrame({'word':list(fdist.keys()), 'count':list(fdist.values())})

    #Selecting top 20 most frequent words 
    
    d = words_df_nhsrev.nlargest(columns="count", n = terms)
    plt.figure(figsize=(20,5))
    ax = sns.barplot(data=d, x="word", y="count", palette="rainbow")
    ax.set(ylabel="Count")
    plt.show()

# %%
freq_words(df_nhsrev['content'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_29624\546779942.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=d, x="word", y="count", palette="rainbow")

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\user\miniconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\user\miniconda3\lib\site-packages (from textblob) (3.9.3)
# Requirement already satisfied: click in c:\users\user\miniconda3\lib\site-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in c:\users\user\miniconda3\lib\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\miniconda3\lib\site-packages (from nltk>=3.9->textblob) (2026.2.28)
# Requirement already satisfied: tqdm in c:\users\user\miniconda3\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\user\miniconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)

# %%
from textblob import TextBlob

# %%
#buat label 
import pandas as pd
df = pd.read_csv(r"C:\Users\USER\Documents\PBA\Week3\2_sentiment_polarity_subjectivity\labelling1.csv")

df.head()
# Out:
#                                reviewId             userName  \
# 0  6d130fcb-47b1-42fc-a032-bf97719ca5a4  Alexander Benkstein
# 1  34f4642b-17ee-463b-ac28-05a902db1cb9        Thomas Watson
# 2  5a9342d9-8259-4c6f-b8b8-20b1096cf69d          Matt Winter
# 3  73a714db-ceb1-4b5d-a1af-64d953643ad9          Hugo Arista
# 4  79b2321f-1e26-4028-b553-da8b0d8896b4              Laura R
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  principally good app pretty much unusable your...      2              0
# 1                          like far ill report later      3              0
# 2  would load real assistance common days easier ...      1              1
# 3  experience app really good thing tools availab...      4              0
# 4  app complete failure planner used kanban board...      1              1
#
#   reviewCreatedVersion               at replyContent repliedAt appVersion  \
# 0              1.18.36   3/3/2026 15:08          NaN       NaN    1.18.36
# 1              1.18.36  2/27/2026 11:03          NaN       NaN    1.18.36
# 2              1.18.36   2/27/2026 5:43          NaN       NaN    1.18.36
# 3              1.18.36  2/24/2026 23:49          NaN       NaN    1.18.36
# 4              1.18.33   2/17/2026 5:10          NaN       NaN    1.18.33
#
#    review_length sentiment  scoreLabel
# 0            190  negative         NaN
# 1             42   neutral         NaN
# 2            257  negative         NaN
# 3            252  positive         NaN
# 4            490  negative         NaN

# %%
#search for the score number exist
print(df[["content","score"]])
# Out:
#                                                 content  score
# 0     principally good app pretty much unusable your...      2
# 1                             like far ill report later      3
# 2     would load real assistance common days easier ...      1
# 3     experience app really good thing tools availab...      4
# 4     app complete failure planner used kanban board...      1
# ...                                                 ...    ...
# 2825  limited functionality cant add tasks plans nor...      2
# 2826                                         works well      5
# 2827                fantastic waiting looks works great      5
# 2828    good first version excited planner capabilities      5
# 2829                                       clean simple      5
#
# [2830 rows x 2 columns]

# %%
#make a label : 
# Percent	Label
# ≥50	positive
# 40–49	neutral
# <40	negative

def sentiment_label(score):
    if score > 3:
        return("positive")
    elif score < 3:
        return("negative")
    else:
        return("neutral")
    df["sentiment"] = df["score"].apply(sentiment_label)
    return df
print(df)
# Out:
#                                   reviewId             userName  \
# 0     6d130fcb-47b1-42fc-a032-bf97719ca5a4  Alexander Benkstein
# 1     34f4642b-17ee-463b-ac28-05a902db1cb9        Thomas Watson
# 2     5a9342d9-8259-4c6f-b8b8-20b1096cf69d          Matt Winter
# 3     73a714db-ceb1-4b5d-a1af-64d953643ad9          Hugo Arista
# 4     79b2321f-1e26-4028-b553-da8b0d8896b4              Laura R
# ...                                    ...                  ...
# 2825  318d375e-2bdc-47c3-b7a7-02fd990b5f98        A Google user
# 2826  b1724cc5-74ad-4ec7-a344-a80ba3d618f9        A Google user
# 2827  bf702dd6-0905-45ac-bcec-a5f06e85cfc7        A Google user
# 2828  092720c3-756b-47b0-bde7-3b8d36e3527c        A Google user
# 2829  e530c92a-e786-4239-b8b2-2ccc11240253        A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/ALV-U...
# 1     https://play-lh.googleusercontent.com/a/ACg8oc...
# 2     https://play-lh.googleusercontent.com/a-/ALV-U...
# 3     https://play-lh.googleusercontent.com/a/ACg8oc...
# 4     https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                 ...
# 2825  https://play-lh.googleusercontent.com/EGemoI2N...
# 2826  https://play-lh.googleusercontent.com/EGemoI2N...
# 2827  https://play-lh.googleusercontent.com/EGemoI2N...
# 2828  https://play-lh.googleusercontent.com/EGemoI2N...
# 2829  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                 content  score  thumbsUpCount  \
# 0     principally good app pretty much unusable your...      2              0
# 1                             like far ill report later      3              0
# 2     would load real assistance common days easier ...      1              1
# 3     experience app really good thing tools availab...      4              0
# 4     app complete failure planner used kanban board...      1              1
# ...                                                 ...    ...            ...
# 2825  limited functionality cant add tasks plans nor...      2              1
# 2826                                         works well      5              3
# 2827                fantastic waiting looks works great      5              4
# 2828    good first version excited planner capabilities      5              4
# 2829                                       clean simple      5              5
#
#      reviewCreatedVersion               at replyContent repliedAt appVersion  \
# 0                 1.18.36   3/3/2026 15:08          NaN       NaN    1.18.36
# 1                 1.18.36  2/27/2026 11:03          NaN       NaN    1.18.36
# 2                 1.18.36   2/27/2026 5:43          NaN       NaN    1.18.36
# 3                 1.18.36  2/24/2026 23:49          NaN       NaN    1.18.36
# 4                 1.18.33   2/17/2026 5:10          NaN       NaN    1.18.33
# ...                   ...              ...          ...       ...        ...
# 2825                    1  5/31/2017 23:10          NaN       NaN          1
# 2826                    1  5/31/2017 23:05          NaN       NaN          1
# 2827                  NaN  5/31/2017 10:52          NaN       NaN        NaN
# 2828                    1   5/31/2017 9:08          NaN       NaN          1
# 2829                  NaN   5/31/2017 8:14          NaN       NaN        NaN
#
#       review_length sentiment
# 0               190  negative
# 1                42   neutral
# 2               257  negative
# 3               252  positive
# 4               490  negative
# ...             ...       ...
# 2825            103  negative
# 2826             11  positive
# 2827             71  positive
# 2828             60  positive
# 2829             17  positive
#
# [2830 rows x 13 columns]

# %%
df.to_csv(r"C:\Users\USER\Documents\PBA\Week3\1_exercise_Individual_labelling\labelling.csv", index=False)

# %%
#Sentiment Polarity 
from textblob import TextBlob

def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

# %%
df["polarity"] = df["content"].apply(get_sentiment)

# %%
print(df[["content", "polarity"]])
# Out:
#                                                 content  polarity
# 0     principally good app pretty much unusable your...  0.350000
# 1                             like far ill report later -0.133333
# 2     would load real assistance common days easier ...  0.010000
# 3     experience app really good thing tools availab...  0.482143
# 4     app complete failure planner used kanban board... -0.072222
# ...                                                 ...       ...
# 2825  limited functionality cant add tasks plans nor... -0.107143
# 2826                                         works well  0.000000
# 2827                fantastic waiting looks works great  0.600000
# 2828    good first version excited planner capabilities  0.441667
# 2829                                       clean simple  0.183333
#
# [2830 rows x 2 columns]

# %%
df.head()
# Out:
#                                reviewId             userName  \
# 0  6d130fcb-47b1-42fc-a032-bf97719ca5a4  Alexander Benkstein
# 1  34f4642b-17ee-463b-ac28-05a902db1cb9        Thomas Watson
# 2  5a9342d9-8259-4c6f-b8b8-20b1096cf69d          Matt Winter
# 3  73a714db-ceb1-4b5d-a1af-64d953643ad9          Hugo Arista
# 4  79b2321f-1e26-4028-b553-da8b0d8896b4              Laura R
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  principally good app pretty much unusable your...      2              0
# 1                          like far ill report later      3              0
# 2  would load real assistance common days easier ...      1              1
# 3  experience app really good thing tools availab...      4              0
# 4  app complete failure planner used kanban board...      1              1
#
#   reviewCreatedVersion               at replyContent repliedAt appVersion  \
# 0              1.18.36   3/3/2026 15:08          NaN       NaN    1.18.36
# 1              1.18.36  2/27/2026 11:03          NaN       NaN    1.18.36
# 2              1.18.36   2/27/2026 5:43          NaN       NaN    1.18.36
# 3              1.18.36  2/24/2026 23:49          NaN       NaN    1.18.36
# 4              1.18.33   2/17/2026 5:10          NaN       NaN    1.18.33
#
#    review_length sentiment  scoreLabel  polarity
# 0            190  negative         NaN  0.350000
# 1             42   neutral         NaN -0.133333
# 2            257  negative         NaN  0.010000
# 3            252  positive         NaN  0.482143
# 4            490  negative         NaN -0.072222

# %%
def sentiment_label(score):
    if score > 0:
        return "positive"
    elif score < 0:
        return "negative"
    else:
        return "neutral"

df["sentiment"] = df["polarity"].apply(sentiment_label)

# %%
print(df[["sentiment","polarity"]])
# Out:
#      sentiment  polarity
# 0     positive  0.350000
# 1     negative -0.133333
# 2     positive  0.010000
# 3     positive  0.482143
# 4     negative -0.072222
# ...        ...       ...
# 2825  negative -0.107143
# 2826   neutral  0.000000
# 2827  positive  0.600000
# 2828  positive  0.441667
# 2829  positive  0.183333
#
# [2830 rows x 2 columns]

# %%
df.head()
# Out:
#                                reviewId             userName  \
# 0  6d130fcb-47b1-42fc-a032-bf97719ca5a4  Alexander Benkstein
# 1  34f4642b-17ee-463b-ac28-05a902db1cb9        Thomas Watson
# 2  5a9342d9-8259-4c6f-b8b8-20b1096cf69d          Matt Winter
# 3  73a714db-ceb1-4b5d-a1af-64d953643ad9          Hugo Arista
# 4  79b2321f-1e26-4028-b553-da8b0d8896b4              Laura R
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  principally good app pretty much unusable your...      2              0
# 1                          like far ill report later      3              0
# 2  would load real assistance common days easier ...      1              1
# 3  experience app really good thing tools availab...      4              0
# 4  app complete failure planner used kanban board...      1              1
#
#   reviewCreatedVersion               at replyContent repliedAt appVersion  \
# 0              1.18.36   3/3/2026 15:08          NaN       NaN    1.18.36
# 1              1.18.36  2/27/2026 11:03          NaN       NaN    1.18.36
# 2              1.18.36   2/27/2026 5:43          NaN       NaN    1.18.36
# 3              1.18.36  2/24/2026 23:49          NaN       NaN    1.18.36
# 4              1.18.33   2/17/2026 5:10          NaN       NaN    1.18.33
#
#    review_length sentiment  scoreLabel  polarity
# 0            190  positive         NaN  0.350000
# 1             42  negative         NaN -0.133333
# 2            257  positive         NaN  0.010000
# 3            252  positive         NaN  0.482143
# 4            490  negative         NaN -0.072222

# %%
df["sentiment"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='sentiment'>

# %%
def get_subjectivity(polarity):

    if polarity == 0:
        return("The text is objective")
    elif polarity > 0: 
        return("The text is subjective and positive")
    else :
        return("The text is subjective and negative")

# %%
df["subjectivity"] = df["polarity"].apply(get_subjectivity)

# %%
print(df[["content", "subjectivity"]])
# Out:
#                                                 content  \
# 0     principally good app pretty much unusable your...
# 1                             like far ill report later
# 2     would load real assistance common days easier ...
# 3     experience app really good thing tools availab...
# 4     app complete failure planner used kanban board...
# ...                                                 ...
# 2825  limited functionality cant add tasks plans nor...
# 2826                                         works well
# 2827                fantastic waiting looks works great
# 2828    good first version excited planner capabilities
# 2829                                       clean simple
#
#                              subjectivity
# 0     The text is subjective and positive
# 1     The text is subjective and negative
# 2     The text is subjective and positive
# 3     The text is subjective and positive
# 4     The text is subjective and negative
# ...                                   ...
# 2825  The text is subjective and negative
# 2826                The text is objective
# 2827  The text is subjective and positive
# 2828  The text is subjective and positive
# 2829  The text is subjective and positive
#
# [2830 rows x 2 columns]

# %%
df.head()
# Out:
#                                reviewId             userName  \
# 0  6d130fcb-47b1-42fc-a032-bf97719ca5a4  Alexander Benkstein
# 1  34f4642b-17ee-463b-ac28-05a902db1cb9        Thomas Watson
# 2  5a9342d9-8259-4c6f-b8b8-20b1096cf69d          Matt Winter
# 3  73a714db-ceb1-4b5d-a1af-64d953643ad9          Hugo Arista
# 4  79b2321f-1e26-4028-b553-da8b0d8896b4              Laura R
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  principally good app pretty much unusable your...      2              0
# 1                          like far ill report later      3              0
# 2  would load real assistance common days easier ...      1              1
# 3  experience app really good thing tools availab...      4              0
# 4  app complete failure planner used kanban board...      1              1
#
#   reviewCreatedVersion               at replyContent repliedAt appVersion  \
# 0              1.18.36   3/3/2026 15:08          NaN       NaN    1.18.36
# 1              1.18.36  2/27/2026 11:03          NaN       NaN    1.18.36
# 2              1.18.36   2/27/2026 5:43          NaN       NaN    1.18.36
# 3              1.18.36  2/24/2026 23:49          NaN       NaN    1.18.36
# 4              1.18.33   2/17/2026 5:10          NaN       NaN    1.18.33
#
#    review_length sentiment  scoreLabel  polarity  \
# 0            190  positive         NaN  0.350000
# 1             42  negative         NaN -0.133333
# 2            257  positive         NaN  0.010000
# 3            252  positive         NaN  0.482143
# 4            490  negative         NaN -0.072222
#
#                           subjectivity
# 0  The text is subjective and positive
# 1  The text is subjective and negative
# 2  The text is subjective and positive
# 3  The text is subjective and positive
# 4  The text is subjective and negative

# %%
new_csv = df.to_csv(r"C:\Users\USER\Documents\PBA\Week3\2_sentiment_polarity_subjectivity\polarityAndSubjectivity.csv", index=False)
