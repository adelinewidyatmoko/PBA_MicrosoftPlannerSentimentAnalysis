# %%
# !pip install google_play_scraper
# !pip install textblob
# Out:
# Requirement already satisfied: google_play_scraper in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (1.2.7)
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the 'C:\Users\USER\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: textblob in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from textblob) (3.9.2)
# Requirement already satisfied: joblib in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: click in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from nltk>=3.9->textblob) (2026.1.15)
# Requirement already satisfied: tqdm in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from nltk>=3.9->textblob) (4.67.3)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the 'C:\Users\USER\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (3.9.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.60.2)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the 'C:\Users\USER\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
from google_play_scraper import app , Sort , reviews_all
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.dates as dates

# %%
nhs_reviews = reviews_all(
    'com.microsoft.planner',
    sleep_milliseconds=0,
    lang='en',
    sort=Sort.NEWEST
)

# %%
print(nhs_reviews[:5])
# Out:
# [{'reviewId': '6d130fcb-47b1-42fc-a032-bf97719ca5a4', 'userName': 'Alexander Benkstein', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUScPRYctvqJtDo8Eak8fUhcA3vhyQuaWFp0IXSYy_3YH6GyX1G', 'content': "Principally a good app but pretty much unusable if you're using more than one MS account on one device. For Word, Excel and other MS apps it's pretty eas to switch but not for Planner. Why!?", 'score': 2, 'thumbsUpCount': 0, 'reviewCreatedVersion': '1.18.36', 'at': datetime.datetime(2026, 3, 3, 15, 8, 44), 'replyContent': None, 'repliedAt': None, 'appVersion': '1.18.36'}, {'reviewId': '34f4642b-17ee-463b-ac28-05a902db1cb9', 'userName': 'Thomas Watson', 'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLh8-a8xAygziLnp2pTUs6e1BlxCbgzgMyyf9O25o6Xa-uyfw=mo', 'content': "I like it so far. I'll report in later....", 'score': 3, 'thumbsUpCount': 0, 'reviewCreatedVersion': '1.18.36', 'at': datetime.datetime(2026, 2, 27, 11, 3, 15), 'replyContent': None, 'repliedAt': None, 'appVersion': '1.18.36'}, {'reviewId': '5a9342d9-8259-4c6f-b8b8-20b1096cf69d', 'userName': 'Matt Winter', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX0oSroKnGl7Dq8N9QP4ehkGGBPNqHUQX0RTL65AhW3z76PKQ5B', 'content': 'It would not load. No real assistance, which is more common these days. There are easier, more reliable apps available. Edit: whats the point? Cant register my device because they cant accept mobiles? Pointless. there would be no stars if that was possible.', 'score': 1, 'thumbsUpCount': 1, 'reviewCreatedVersion': '1.18.36', 'at': datetime.datetime(2026, 2, 27, 5, 43, 15), 'replyContent': None, 'repliedAt': None, 'appVersion': '1.18.36'}, {'reviewId': '73a714db-ceb1-4b5d-a1af-64d953643ad9', 'userName': 'Hugo Arista', 'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKHbuy2yFbJ5AGe3PZXkx5Hdj84pTisYLmQ2E6LqV_pYO6w1A=mo', 'content': 'My experience with this app has been really good, the only thing is that the tools available on the app are really limited. It would be ideal to have more capabilities to work between diferent plans (moving a card between plans like on the web version)', 'score': 4, 'thumbsUpCount': 0, 'reviewCreatedVersion': '1.18.36', 'at': datetime.datetime(2026, 2, 24, 23, 49, 27), 'replyContent': None, 'repliedAt': None, 'appVersion': '1.18.36'}, {'reviewId': '79b2321f-1e26-4028-b553-da8b0d8896b4', 'userName': 'Laura R', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXMp1jpKbalrYWfxVjbiIvC5uQ0F9zO6E_Brlhx83pdSPr9yjKV-A', 'content': 'This app is a complete failure. Planner used to be a kanban board app. The mobile version now ignores the board structure and collapses buckets into one list even though they exist and work in the web app. Reinstalling and settings changes don’t fix it because the functionality is simply gone. You can’t manage workflow stages or visualize progress anymore. The website works, Teams works, but the official app can’t display its own data model. Please restore board view or rename the app.', 'score': 1, 'thumbsUpCount': 1, 'reviewCreatedVersion': '1.18.33', 'at': datetime.datetime(2026, 2, 17, 5, 10, 32), 'replyContent': None, 'repliedAt': None, 'appVersion': '1.18.33'}]

# %%
df_nhsrev = pd.DataFrame(np.array(nhs_reviews),columns=['content'])
df_nhsrev = df_nhsrev.join(pd.DataFrame(df_nhsrev.pop('content').tolist()))
df_nhsrev.to_csv(r'C:\Users\USER\Documents\PBA\SentimentAnalysis\df_plannerReview.csv',index=False)
df_nhsrev.head()
# Out:
#                                reviewId             userName  \
# 0  6d130fcb-47b1-42fc-a032-bf97719ca5a4  Alexander Benkstein
# 1  34f4642b-17ee-463b-ac28-05a902db1cb9        Thomas Watson
# 2  5a9342d9-8259-4c6f-b8b8-20b1096cf69d          Matt Winter
# 3  73a714db-ceb1-4b5d-a1af-64d953643ad9          Hugo Arista
# 4  79b2321f-1e26-4028-b553-da8b0d8896b4              Laura R
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Principally a good app but pretty much unusabl...      2              0
# 1         I like it so far. I'll report in later....      3              0
# 2  It would not load. No real assistance, which i...      1              1
# 3  My experience with this app has been really go...      4              0
# 4  This app is a complete failure. Planner used t...      1              1
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0              1.18.36 2026-03-03 15:08:44         None       NaT    1.18.36
# 1              1.18.36 2026-02-27 11:03:15         None       NaT    1.18.36
# 2              1.18.36 2026-02-27 05:43:15         None       NaT    1.18.36
# 3              1.18.36 2026-02-24 23:49:27         None       NaT    1.18.36
# 4              1.18.33 2026-02-17 05:10:32         None       NaT    1.18.33

# %%
#clean the content column (impossible because we cannot control people's reviews) 
# EDA (Explnatory Data Analysis ) 
#1. size of the data :
def shape(df):
    rows,col = df.shape
    print(f"the dataset contains {rows} reviews and {col} columns.")
shape(df_nhsrev)
# Out:
# the dataset contains 2837 reviews and 11 columns.

# %%
#2. rating distribution : to evaluate the order through the data score. 
#It is stated the valued for the highest stake comes down at 1 rating (39.74%) while the lowest at 4 rating (8.78%). 
df_rating = df_nhsrev["score"].value_counts().sort_index().plot(kind="bar")

# %%
def rating_summarize(df): 
    rating_score = df_nhsrev['score'].value_counts().sort_index()
    total = len(df)

    for rating, count in rating_score.items():
         percent = round((count/total)*100,2)
         print(f"{rating} star : {count} reviews ({percent}%)")
rating_summarize(df_nhsrev)
# Out:
# 1 star : 549 reviews (19.35%)
# 2 star : 169 reviews (5.96%)
# 3 star : 270 reviews (9.52%)
# 4 star : 566 reviews (19.95%)
# 5 star : 1283 reviews (45.22%)

# %%
df_nhsrev["review_length"] = df_nhsrev.content.str.len()
df_nhsrev["review_length"].describe()
# Out:
# count    2837.00000
# mean       87.69933
# std        97.17882
# min         1.00000
# 25%        22.00000
# 50%        55.00000
# 75%       116.00000
# max       931.00000
# Name: review_length, dtype: float64

# %%
#3. Checking most common words 
all_text = " ".join(df_nhsrev["content"].astype(str))
print(all_text[:500])
# Out:
# Principally a good app but pretty much unusable if you're using more than one MS account on one device. For Word, Excel and other MS apps it's pretty eas to switch but not for Planner. Why!? I like it so far. I'll report in later.... It would not load. No real assistance, which is more common these days. There are easier, more reliable apps available. Edit: whats the point? Cant register my device because they cant accept mobiles? Pointless. there would be no stars if that was possible. My exper

# %%
#DATA PREPROCESSING
# Lower casing

# Change the reviews type to string
df_nhsrev['content'] = df_nhsrev['content'].astype(str)# Before lowercasing
# Before lowercasing
print(df_nhsrev['content'].head())
# Out:
# 0    Principally a good app but pretty much unusabl...
# 1           I like it so far. I'll report in later....
# 2    It would not load. No real assistance, which i...
# 3    My experience with this app has been really go...
# 4    This app is a complete failure. Planner used t...
# Name: content, dtype: object

# %%
#lowercasing the reviews 
#Lowercase all reviews to see the difference
df_nhsrev['content']= df_nhsrev['content'].apply(lambda x: x.lower())
print(df_nhsrev['content'].head())
# Out:
# 0    principally a good app but pretty much unusabl...
# 1           i like it so far. i'll report in later....
# 2    it would not load. no real assistance, which i...
# 3    my experience with this app has been really go...
# 4    this app is a complete failure. planner used t...
# Name: content, dtype: object

# %%
#REMOVE PUNCTUATION 
import re

df_nhsrev["content"] = df_nhsrev["content"].apply(lambda x: re.sub(r"[^\w\s]", "", x))
print(df_nhsrev["content"].tail())
# Out:
# 2832    limited functionality  cant add tasks or plans...
# 2833                                           works well
# 2834    fantastic this is what i was waiting for and i...
# 2835    a good first version excited for more planner ...
# 2836                                     clean and simple
# Name: content, dtype: object

# %%
#REMOVE STOPWORDS
# !pip install nltk
import nltk
nltk.download('stopwords')
# Out:
# Requirement already satisfied: nltk in c:\users\user\miniconda3\lib\site-packages (3.9.3)
# Requirement already satisfied: click in c:\users\user\miniconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\user\miniconda3\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\miniconda3\lib\site-packages (from nltk) (2026.2.28)
# Requirement already satisfied: tqdm in c:\users\user\miniconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\user\miniconda3\lib\site-packages (from click->nltk) (0.4.6)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.probability import FreqDist
stop_words = set(stopwords.words("english"))

# %%
df_nhsrev["content"] = df_nhsrev["content"].apply(
    lambda x: " ".join(word for word in x.split() if word not in stop_words)
)

# %%
df_nhsrev["content"].tail()
# Out:
# 2832    limited functionality cant add tasks plans nor...
# 2833                                           works well
# 2834                  fantastic waiting looks works great
# 2835      good first version excited planner capabilities
# 2836                                         clean simple
# Name: content, dtype: object

# %%
df_nhsrev.to_csv(
"C:/Users/USER/Documents/PBA/SentimentAnalysis/planner_clean_reviews.csv",
index=False
)

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting numpy!=1.24.0,>=1.20 (from seaborn)
#   Downloading numpy-2.4.2-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting pandas>=1.2 (from seaborn)
#   Downloading pandas-3.0.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Downloading matplotlib-3.10.8-cp313-cp313-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading fonttools-4.61.1-cp313-cp313-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pillow-12.1.1-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting python-dateutil>=2.7 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting tzdata (from pandas>=1.2->seaborn)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading matplotlib-3.10.8-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 1.3 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/8.1 MB 1.4 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.0/8.1 MB 1.4 MB/s eta 0:00:06
#    ------ --------------------------------- 1.3/8.1 MB 1.3 MB/s eta 0:00:06
#    ------- -------------------------------- 1.6/8.1 MB 1.2 MB/s eta 0:00:06
#    --------- ------------------------------ 1.8/8.1 MB 1.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.1/8.1 MB 1.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.4/8.1 MB 1.2 MB/s eta 0:00:05
#    ------------ --------------------------- 2.6/8.1 MB 1.3 MB/s eta 0:00:05
#    -------------- ------------------------- 2.9/8.1 MB 1.3 MB/s eta 0:00:05
#    --------------- ------------------------ 3.1/8.1 MB 1.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.4/8.1 MB 1.2 MB/s eta 0:00:04
#    ------------------ --------------------- 3.7/8.1 MB 1.2 MB/s eta 0:00:04
#    ------------------- -------------------- 3.9/8.1 MB 1.2 MB/s eta 0:00:04
#    -------------------- ------------------- 4.2/8.1 MB 1.2 MB/s eta 0:00:04
#    --------------------- ------------------ 4.5/8.1 MB 1.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.7/8.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------ --------------- 5.0/8.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------- -------------- 5.2/8.1 MB 1.2 MB/s eta 0:00:03
#    --------------------------- ------------ 5.5/8.1 MB 1.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 5.8/8.1 MB 1.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.8/8.1 MB 1.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.1 MB 1.2 MB/s eta 0:00:02
#    ------------------------------ --------- 6.3/8.1 MB 1.2 MB/s eta 0:00:02
#    -------------------------------- ------- 6.6/8.1 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 7.1/8.1 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 1.2 MB/s  0:00:06
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.3 MB 1.4 MB/s eta 0:00:02
#    ------------- -------------------------- 0.8/2.3 MB 1.1 MB/s eta 0:00:02
#    ------------------ --------------------- 1.0/2.3 MB 1.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.3/2.3 MB 1.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.6/2.3 MB 1.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------ --- 2.1/2.3 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 1.2 MB/s  0:00:01
# Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl (73 kB)
# Downloading numpy-2.4.2-cp313-cp313-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.3 MB 1.3 MB/s eta 0:00:10
#    -- ------------------------------------- 0.8/12.3 MB 1.3 MB/s eta 0:00:10
#    --- ------------------------------------ 1.0/12.3 MB 1.2 MB/s eta 0:00:10
#    ---- ----------------------------------- 1.3/12.3 MB 1.2 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.6/12.3 MB 1.2 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.8/12.3 MB 1.2 MB/s eta 0:00:09
#    ------ --------------------------------- 2.1/12.3 MB 1.2 MB/s eta 0:00:09
#    ------- -------------------------------- 2.4/12.3 MB 1.2 MB/s eta 0:00:09
#    -------- ------------------------------- 2.6/12.3 MB 1.2 MB/s eta 0:00:08
#    --------- ------------------------------ 2.9/12.3 MB 1.2 MB/s eta 0:00:08
#    ---------- ----------------------------- 3.1/12.3 MB 1.2 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.4/12.3 MB 1.2 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.4/12.3 MB 1.2 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.7/12.3 MB 1.2 MB/s eta 0:00:08
#    ------------ --------------------------- 3.9/12.3 MB 1.2 MB/s eta 0:00:08
#    ------------- -------------------------- 4.2/12.3 MB 1.2 MB/s eta 0:00:07
#    -------------- ------------------------- 4.5/12.3 MB 1.2 MB/s eta 0:00:07
#    --------------- ------------------------ 4.7/12.3 MB 1.2 MB/s eta 0:00:07
#    ---------------- ----------------------- 5.0/12.3 MB 1.2 MB/s eta 0:00:07
#    ----------------- ---------------------- 5.2/12.3 MB 1.2 MB/s eta 0:00:07
#    ----------------- ---------------------- 5.5/12.3 MB 1.2 MB/s eta 0:00:06
#    ------------------ --------------------- 5.8/12.3 MB 1.2 MB/s eta 0:00:06
#    ------------------- -------------------- 6.0/12.3 MB 1.2 MB/s eta 0:00:06
#    -------------------- ------------------- 6.3/12.3 MB 1.2 MB/s eta 0:00:06
#    --------------------- ------------------ 6.6/12.3 MB 1.2 MB/s eta 0:00:05
#    --------------------- ------------------ 6.6/12.3 MB 1.2 MB/s eta 0:00:05
#    ---------------------- ----------------- 6.8/12.3 MB 1.2 MB/s eta 0:00:05
#    ---------------------- ----------------- 7.1/12.3 MB 1.2 MB/s eta 0:00:05
#    ------------------------ --------------- 7.6/12.3 MB 1.2 MB/s eta 0:00:04
#    ------------------------- -------------- 7.9/12.3 MB 1.2 MB/s eta 0:00:04
#    -------------------------- ------------- 8.1/12.3 MB 1.2 MB/s eta 0:00:04
#    -------------------------- ------------- 8.1/12.3 MB 1.2 MB/s eta 0:00:04
#    --------------------------- ------------ 8.4/12.3 MB 1.2 MB/s eta 0:00:04
#    ---------------------------- ----------- 8.7/12.3 MB 1.2 MB/s eta 0:00:04
#    ---------------------------- ----------- 8.9/12.3 MB 1.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 9.2/12.3 MB 1.2 MB/s eta 0:00:03
#    ------------------------------ --------- 9.4/12.3 MB 1.2 MB/s eta 0:00:03
#    ------------------------------- -------- 9.7/12.3 MB 1.2 MB/s eta 0:00:03
#    -------------------------------- ------- 10.0/12.3 MB 1.2 MB/s eta 0:00:02
#    --------------------------------- ------ 10.2/12.3 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.5/12.3 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.7/12.3 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.0/12.3 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 11.3/12.3 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------ --- 11.3/12.3 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.3 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 11.8/12.3 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 1.2 MB/s  0:00:10
# Downloading pandas-3.0.1-cp313-cp313-win_amd64.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/9.7 MB 1.2 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.0/9.7 MB 1.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.3/9.7 MB 1.2 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/9.7 MB 1.2 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/9.7 MB 1.2 MB/s eta 0:00:07
#    -------- ------------------------------- 2.1/9.7 MB 1.2 MB/s eta 0:00:07
#    --------- ------------------------------ 2.4/9.7 MB 1.2 MB/s eta 0:00:07
#    ---------- ----------------------------- 2.6/9.7 MB 1.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.6/9.7 MB 1.2 MB/s eta 0:00:06
#    ------------ --------------------------- 3.1/9.7 MB 1.2 MB/s eta 0:00:06
#    ------------ --------------------------- 3.1/9.7 MB 1.2 MB/s eta 0:00:06
#    ------------- -------------------------- 3.4/9.7 MB 1.2 MB/s eta 0:00:06
#    --------------- ------------------------ 3.7/9.7 MB 1.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 3.9/9.7 MB 1.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.2/9.7 MB 1.2 MB/s eta 0:00:05
#    ------------------ --------------------- 4.5/9.7 MB 1.2 MB/s eta 0:00:05
#    ------------------- -------------------- 4.7/9.7 MB 1.2 MB/s eta 0:00:05
#    -------------------- ------------------- 5.0/9.7 MB 1.2 MB/s eta 0:00:04
#    --------------------- ------------------ 5.2/9.7 MB 1.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.5/9.7 MB 1.2 MB/s eta 0:00:04
#    ------------------------ --------------- 6.0/9.7 MB 1.2 MB/s eta 0:00:04
#    ------------------------ --------------- 6.0/9.7 MB 1.2 MB/s eta 0:00:04
#    ------------------------- -------------- 6.3/9.7 MB 1.2 MB/s eta 0:00:03
#    -------------------------- ------------- 6.6/9.7 MB 1.2 MB/s eta 0:00:03
#    --------------------------- ------------ 6.8/9.7 MB 1.2 MB/s eta 0:00:03
#    ------------------------------ --------- 7.3/9.7 MB 1.2 MB/s eta 0:00:02
#    ------------------------------ --------- 7.3/9.7 MB 1.2 MB/s eta 0:00:02
#    ------------------------------- -------- 7.6/9.7 MB 1.2 MB/s eta 0:00:02
#    -------------------------------- ------- 7.9/9.7 MB 1.2 MB/s eta 0:00:02
#    --------------------------------- ------ 8.1/9.7 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 8.4/9.7 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 8.7/9.7 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.7 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.7 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.7 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 1.2 MB/s  0:00:08
# Downloading pillow-12.1.1-cp313-cp313-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.0 MB 1.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 0.8/7.0 MB 1.2 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.0/7.0 MB 1.2 MB/s eta 0:00:06
#    ------- -------------------------------- 1.3/7.0 MB 1.1 MB/s eta 0:00:06
#    -------- ------------------------------- 1.6/7.0 MB 1.2 MB/s eta 0:00:05
#    ---------- ----------------------------- 1.8/7.0 MB 1.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.1/7.0 MB 1.2 MB/s eta 0:00:05
#    ------------- -------------------------- 2.4/7.0 MB 1.2 MB/s eta 0:00:04
#    -------------- ------------------------- 2.6/7.0 MB 1.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 2.9/7.0 MB 1.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 3.1/7.0 MB 1.2 MB/s eta 0:00:04
#    ------------------- -------------------- 3.4/7.0 MB 1.2 MB/s eta 0:00:04
#    -------------------- ------------------- 3.7/7.0 MB 1.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.9/7.0 MB 1.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.2/7.0 MB 1.2 MB/s eta 0:00:03
#    ------------------------- -------------- 4.5/7.0 MB 1.2 MB/s eta 0:00:03
#    -------------------------- ------------- 4.7/7.0 MB 1.2 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 1.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.0/7.0 MB 1.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.2/7.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------- -------- 5.5/7.0 MB 1.2 MB/s eta 0:00:02
#    -------------------------------- ------- 5.8/7.0 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 6.0/7.0 MB 1.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.3/7.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 1.2 MB/s  0:00:05
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, six, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, python-dateutil, contourpy, pandas, matplotlib, seaborn
#
#    ----------------------------------------  0/13 [tzdata]
#    ----------------------------------------  0/13 [tzdata]
#    ----------------------------------------  0/13 [tzdata]
#    ----------------------------------------  0/13 [tzdata]
#    ----------------------------------------  0/13 [tzdata]
#    ----------------------------------------  0/13 [tzdata]
#    ----------------------------------------  0/13 [tzdata]
#    ----------------------------------------  0/13 [tzdata]
#    ----------------------------------------  0/13 [tzdata]
#    ------ ---------------------------------  2/13 [pyparsing]
#    ------ ---------------------------------  2/13 [pyparsing]
#    ------ ---------------------------------  2/13 [pyparsing]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    --------------------- ------------------  7/13 [cycler]
#    ------------------------ ---------------  8/13 [python-dateutil]
#    ------------------------ ---------------  8/13 [python-dateutil]
#    ------------------------ ---------------  8/13 [python-dateutil]
#    --------------------------- ------------  9/13 [contourpy]
#    --------------------------- ------------  9/13 [contourpy]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    ------------------------------ --------- 10/13 [pandas]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ---------------------------------------- 13/13 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 numpy-2.4.2 pandas-3.0.1 pillow-12.1.1 pyparsing-3.3.2 python-dateutil-2.9.0.post0 seaborn-0.13.2 six-1.17.0 tzdata-2025.3

# %%
#COUNT WORD FREQUENCY 

import seaborn as sns
import matplotlib.pyplot as plt
def freq_words(x, terms = 30):
    all_words = ''.join([text for text in x])
    all_words = all_words.split()

    fdist = FreqDist(all_words)
    words_df_nhsrev = pd.DataFrame({'word':list(fdist.keys()), 'count':list(fdist.values())})

    #Selecting top 20 most frequent words 
    
    d = words_df_nhsrev.nlargest(columns="count", n = terms)
    plt.figure(figsize=(20,5))
    ax = sns.barplot(data=d, x="word", y="count", palette="rainbow")
    ax.set(ylabel="Count")
    plt.show()

# %%
freq_words(df_nhsrev['content'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25748\546779942.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=d, x="word", y="count", palette="rainbow")

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\user\miniconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\user\miniconda3\lib\site-packages (from textblob) (3.9.3)
# Requirement already satisfied: click in c:\users\user\miniconda3\lib\site-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in c:\users\user\miniconda3\lib\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\miniconda3\lib\site-packages (from nltk>=3.9->textblob) (2026.2.28)
# Requirement already satisfied: tqdm in c:\users\user\miniconda3\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\user\miniconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)

# %%
from textblob import TextBlob

# %%
#Create Sentiment Function
def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

# %%
df_nhsrev["polarity"] = df_nhsrev["content"].apply(get_sentiment)

# %%
print(df_nhsrev[["content","polarity"]])
# Out:
#                                                 content  polarity
# 0     principally good app pretty much unusable your...  0.350000
# 1                             like far ill report later -0.133333
# 2     would load real assistance common days easier ...  0.010000
# 3     experience app really good thing tools availab...  0.482143
# 4     app complete failure planner used kanban board... -0.072222
# ...                                                 ...       ...
# 2832  limited functionality cant add tasks plans nor... -0.107143
# 2833                                         works well  0.000000
# 2834                fantastic waiting looks works great  0.600000
# 2835    good first version excited planner capabilities  0.441667
# 2836                                       clean simple  0.183333
#
# [2837 rows x 2 columns]

# %%
def sentiment_label(score):
    if score > 0:
        return "positive"
    elif score < 0:
        return "negative"
    else:
        return "neutral"

df_nhsrev["sentiment"] = df_nhsrev["polarity"].apply(sentiment_label)

# %%
df_nhsrev["sentiment"].value_counts()
# Out:
# sentiment
# positive    1864
# neutral      682
# negative     291
# Name: count, dtype: int64

# %%
df_nhsrev["sentiment"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='sentiment'>
